# %% [markdown]
# ## Model-Specific Requirements
#
# ### 1. Decision Tree
# - Classification model
# - Uses the prepared numerical feature set
# - Target: `Label`
# - Important parameters: `criterion`, `max_depth`, `min_samples_split`, `min_samples_leaf`
#
# ### 2. Random Forest
# - Ensemble of Decision Trees
# - Uses the prepared feature set
# - Target: `Label`
# - Important parameters: `n_estimators`, `max_depth`, `min_samples_split`, `min_samples_leaf`
#
# ### 3. AdaBoost
# - Boosting-based classification model
# - Uses the prepared feature set
# - Target: `Label`
# - Important parameters: `n_estimators`, `learning_rate`
#
# ### 4. XGBoost
# - Gradient boosting classification model
# - Uses the prepared feature set
# - Target: `Label`
# - Important parameters: `n_estimators`, `max_depth`, `learning_rate`, `subsample`, `colsample_bytree`
#
# ### 5. LightGBM
# - Gradient boosting classification model
# - Uses the prepared feature set
# - Target: `Label`
# - Important parameters: `n_estimators`, `learning_rate`, `max_depth`, `num_leaves`

# %% [markdown]
# ## Common Model Requirements
#
# | Requirement | Details |
# |---|---|
# | Dataset | CIC-IDS2018 |
# | Task | Multi-class classification |
# | Target | `Label` |
# | Classes | Benign, FTP-BruteForce, SSH-Bruteforce |
# | Input | Network-flow features |
# | Models | Decision Tree, Random Forest, AdaBoost, XGBoost, LightGBM |
# | Training data | To be prepared during later preprocessing/splitting stages |
# | Evaluation | Accuracy, Precision, Recall, F1-score |

# %% [markdown]
# # Day 4 - Model Requirements Review
#
# ## Models
# 1. Decision Tree
# 2. Random Forest
# 3. AdaBoost
# 4. XGBoost
# 5. LightGBM
