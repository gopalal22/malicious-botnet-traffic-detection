# %% [markdown]
# ## Day 12 Completion Note
#
# - Random Forest baseline model was trained successfully.
# - Training input contained 838,860 rows and 78 numeric features.
# - Test input contained 209,715 rows and 78 numeric features.
# - Invalid numeric values were handled by replacing infinite values with NaN and filling missing values using training-data-derived medians.
# - Random Forest configuration:
#   - `random_state=42`
#   - `n_jobs=-1`
# - Test predictions were generated successfully.
# - Baseline evaluation metrics were calculated:
#   - Accuracy: 0.9999523162
#   - Weighted Precision: 0.9999523286
#   - Weighted Recall: 0.9999523162
#   - Weighted F1 Score: 0.9999523161
# - Classification report was generated.
# - Trained model was saved to:
#   `models/random_forest_baseline.joblib`
# - Saved model was successfully loaded and verified.
#
# ### Status
# Day 12 – Random Forest Training: **COMPLETED**

# %%
import os
import joblib

print("Model file exists:", os.path.exists(model_path))

loaded_rf_model = joblib.load(model_path)

print("Loaded model type:", type(loaded_rf_model))
print("Loaded model:", loaded_rf_model)
# Out:
# Model file exists: True
# Loaded model type: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# Loaded model: RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
import joblib

model_path = "../models/random_forest_baseline.joblib"

joblib.dump(rf_model, model_path)

print("Random Forest model saved successfully.")
print("Model path:", model_path)
# Out:
# Random Forest model saved successfully.
# Model path: ../models/random_forest_baseline.joblib

# %%
rf_results = {
    "Model": "Random Forest",
    "Accuracy": rf_accuracy,
    "Precision": rf_precision,
    "Recall": rf_recall,
    "F1 Score": rf_f1
}

print(rf_results)
# Out:
# {'Model': 'Random Forest', 'Accuracy': 0.999952316238705, 'Precision': 0.9999523285658237, 'Recall': 0.999952316238705, 'F1 Score': 0.9999523161430673}

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

rf_accuracy = accuracy_score(y_test, y_pred_rf)

rf_precision = precision_score(
    y_test,
    y_pred_rf,
    average="weighted",
    zero_division=0
)

rf_recall = recall_score(
    y_test,
    y_pred_rf,
    average="weighted",
    zero_division=0
)

rf_f1 = f1_score(
    y_test,
    y_pred_rf,
    average="weighted",
    zero_division=0
)

print("Random Forest Baseline Metrics")
print("--------------------------------")
print("Accuracy :", rf_accuracy)
print("Precision:", rf_precision)
print("Recall   :", rf_recall)
print("F1 Score :", rf_f1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf, zero_division=0))
# Out:
# Random Forest Baseline Metrics
# --------------------------------
# Accuracy : 0.999952316238705
# Precision: 0.9999523285658237
# Recall   : 0.999952316238705
# F1 Score : 0.9999523161430673
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Benign       1.00      1.00      1.00    133525
# FTP-BruteForce       1.00      1.00      1.00     38672
# SSH-Bruteforce       1.00      1.00      1.00     37518
#
#       accuracy                           1.00    209715
#      macro avg       1.00      1.00      1.00    209715
#   weighted avg       1.00      1.00      1.00    209715

# %%
print("Generating Random Forest predictions...")

y_pred_rf = rf_model.predict(X_test_clean)

print("Prediction completed successfully.")
print("Number of predictions:", len(y_pred_rf))
# Out:
# Generating Random Forest predictions...
# Prediction completed successfully.
# Number of predictions: 209715

# %%
print("Starting Random Forest training...")

rf_model.fit(X_train_clean, y_train)

print("Random Forest training completed successfully.")
# Out:
# Starting Random Forest training...
# Random Forest training completed successfully.

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    random_state=42,
    n_jobs=-1
)

print("Random Forest model created successfully.")
print(rf_model)
# Out:
# Random Forest model created successfully.
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# Copy train/test inputs before cleaning
X_train_clean = X_train.copy()
X_test_clean = X_test.copy()

# Convert infinite values to NaN
X_train_clean = X_train_clean.replace([np.inf, -np.inf], np.nan)
X_test_clean = X_test_clean.replace([np.inf, -np.inf], np.nan)

# Calculate medians using TRAINING data only
train_medians = X_train_clean.median()

# Fill missing values using training medians
X_train_clean = X_train_clean.fillna(train_medians)
X_test_clean = X_test_clean.fillna(train_medians)

# Verify cleaned data
print("X_train_clean NaN:", X_train_clean.isna().sum().sum())
print("X_test_clean NaN :", X_test_clean.isna().sum().sum())

print("X_train_clean Inf:", np.isinf(X_train_clean).sum().sum())
print("X_test_clean Inf :", np.isinf(X_test_clean).sum().sum())

print("\nTraining input is finite:",
      np.isfinite(X_train_clean.to_numpy()).all())

print("Testing input is finite:",
      np.isfinite(X_test_clean.to_numpy()).all())
# Out:
# X_train_clean NaN: 0
# X_test_clean NaN : 0
# X_train_clean Inf: 0
# X_test_clean Inf : 0
#
# Training input is finite: True
# Testing input is finite: True

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv("../cic.csv")

X = df.drop(columns=["Label"])
y = df["Label"]

X_numeric = X.select_dtypes(include="number")

X_train, X_test, y_train, y_test = train_test_split(
    X_numeric,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("Training features:", X_train.shape)
print("Testing features :", X_test.shape)
print("Training target  :", y_train.shape)
print("Testing target   :", y_test.shape)
# Out:
# Training features: (838860, 78)
# Testing features : (209715, 78)
# Training target  : (838860,)
# Testing target   : (209715,)

# %% [markdown]
# # Day 12 – Random Forest Training
#
# ## Objective
#
# Train the Random Forest model using the common CIC-IDS2018 training input.
#
# ## Model
#
# Random Forest Classifier
#
# ## Training Input
#
# - Training features: 78 numeric features
# - Training rows: 838,860
# - Target: `Label`
# - Number of target classes: 3
#
# ## Evaluation
#
# The trained model will be evaluated on the test set using:
#
# - Accuracy
# - Weighted Precision
# - Weighted Recall
# - Weighted F1 Score
# - Classification Report
#
# ## Day 12 Scope
#
# - Load the dataset.
# - Create the common train/test split.
# - Handle invalid numeric values using training-data-derived medians.
# - Train the Random Forest model.
# - Generate test predictions.
# - Calculate baseline evaluation metrics.
# - Save the trained model.
#
# Only the Random Forest model will be trained on Day 12.
