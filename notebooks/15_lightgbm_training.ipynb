# %% [markdown]
# ## Day 15 Completion Note
#
# - LightGBM baseline model was trained successfully.
# - Training input contained 838,860 rows and 78 numeric features.
# - Test input contained 209,715 rows and 78 numeric features.
# - Invalid numeric values were handled by replacing infinite values with NaN and filling missing values using training-data-derived medians.
# - Target labels were encoded using `LabelEncoder`.
# - LightGBM configuration included:
#   - `random_state=42`
#   - `objective="multiclass"`
#   - `num_class=3`
#   - `n_jobs=-1`
# - Test predictions were generated successfully.
# - Baseline evaluation metrics were calculated.
# - Classification report was generated.
# - Trained model was saved to:
#   `models/lightgbm_baseline.joblib`
# - Saved model was successfully loaded and verified.
#
# ### Status
# Day 15 – LightGBM Training: **COMPLETED**

# %%
import os
import joblib

print("Model file exists:", os.path.exists(model_path))

loaded_lgbm_model = joblib.load(model_path)

print("Loaded model type:", type(loaded_lgbm_model))
print("Loaded model:", loaded_lgbm_model)
# Out:
# Model file exists: True
# Loaded model type: <class 'lightgbm.sklearn.LGBMClassifier'>
# Loaded model: LGBMClassifier(n_jobs=-1, num_class=3, objective='multiclass', random_state=42)

# %%
import joblib

model_path = "../models/lightgbm_baseline.joblib"

joblib.dump(lgbm_model, model_path)

print("LightGBM model saved successfully.")
print("Model path:", model_path)
# Out:
# LightGBM model saved successfully.
# Model path: ../models/lightgbm_baseline.joblib

# %%
lgbm_results = {
    "Model": "LightGBM",
    "Accuracy": lgbm_accuracy,
    "Precision": lgbm_precision,
    "Recall": lgbm_recall,
    "F1 Score": lgbm_f1
}

print(lgbm_results)
# Out:
# {'Model': 'LightGBM', 'Accuracy': 0.999952316238705, 'Precision': 0.9999523285658237, 'Recall': 0.999952316238705, 'F1 Score': 0.9999523161430673}

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

lgbm_accuracy = accuracy_score(y_test, y_pred_lgbm)

lgbm_precision = precision_score(
    y_test,
    y_pred_lgbm,
    average="weighted",
    zero_division=0
)

lgbm_recall = recall_score(
    y_test,
    y_pred_lgbm,
    average="weighted",
    zero_division=0
)

lgbm_f1 = f1_score(
    y_test,
    y_pred_lgbm,
    average="weighted",
    zero_division=0
)

print("LightGBM Baseline Metrics")
print("--------------------------------")
print("Accuracy :", lgbm_accuracy)
print("Precision:", lgbm_precision)
print("Recall   :", lgbm_recall)
print("F1 Score :", lgbm_f1)

print("\nClassification Report:")
print(classification_report(
    y_test,
    y_pred_lgbm,
    zero_division=0
))
# Out:
# LightGBM Baseline Metrics
# --------------------------------
# Accuracy : 0.999952316238705
# Precision: 0.9999523285658237
# Recall   : 0.999952316238705
# F1 Score : 0.9999523161430673
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Benign       1.00      1.00      1.00    133525
# FTP-BruteForce       1.00      1.00      1.00     38672
# SSH-Bruteforce       1.00      1.00      1.00     37518
#
#       accuracy                           1.00    209715
#      macro avg       1.00      1.00      1.00    209715
#   weighted avg       1.00      1.00      1.00    209715

# %%
print("Generating LightGBM predictions...")

y_pred_lgbm_encoded = lgbm_model.predict(X_test_clean)

# Convert predictions back to original label names
y_pred_lgbm = label_encoder.inverse_transform(
    y_pred_lgbm_encoded.astype(int)
)

print("Prediction completed successfully.")
print("Number of predictions:", len(y_pred_lgbm))
# Out:
# Generating LightGBM predictions...
# Prediction completed successfully.
# Number of predictions: 209715

# %%
print("Starting LightGBM training...")

lgbm_model.fit(
    X_train_clean,
    y_train_encoded
)

print("LightGBM training completed successfully.")
# Out:
# Starting LightGBM training...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.073284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 13834
# [LightGBM] [Info] Number of data points in the train set: 838860, number of used features: 68
# [LightGBM] [Info] Start training from score -0.451459
# [LightGBM] [Info] Start training from score -1.690634
# [LightGBM] [Info] Start training from score -1.720935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM training completed successfully.

# %%
from lightgbm import LGBMClassifier

lgbm_model = LGBMClassifier(
    random_state=42,
    objective="multiclass",
    num_class=3,
    n_jobs=-1
)

print("LightGBM model created successfully.")
print(lgbm_model)
# Out:
# LightGBM model created successfully.
# LGBMClassifier(n_jobs=-1, num_class=3, objective='multiclass', random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

print("Label classes:")
print(label_encoder.classes_)

print("\nEncoded training labels shape:", y_train_encoded.shape)
print("Encoded testing labels shape :", y_test_encoded.shape)

print("\nEncoded label values:")
print(np.unique(y_train_encoded))
# Out:
# Label classes:
# ['Benign' 'FTP-BruteForce' 'SSH-Bruteforce']
#
# Encoded training labels shape: (838860,)
# Encoded testing labels shape : (209715,)
#
# Encoded label values:
# [0 1 2]

# %%
# Copy train/test inputs before cleaning
X_train_clean = X_train.copy()
X_test_clean = X_test.copy()

# Convert infinite values to NaN
X_train_clean = X_train_clean.replace([np.inf, -np.inf], np.nan)
X_test_clean = X_test_clean.replace([np.inf, -np.inf], np.nan)

# Calculate medians using training data only
train_medians = X_train_clean.median()

# Fill missing values using training medians
X_train_clean = X_train_clean.fillna(train_medians)
X_test_clean = X_test_clean.fillna(train_medians)

# Verify cleaned data
print("X_train_clean NaN:", X_train_clean.isna().sum().sum())
print("X_test_clean NaN :", X_test_clean.isna().sum().sum())

print("X_train_clean Inf:", np.isinf(X_train_clean).sum().sum())
print("X_test_clean Inf :", np.isinf(X_test_clean).sum().sum())

print("\nTraining input is finite:",
      np.isfinite(X_train_clean.to_numpy()).all())

print("Testing input is finite:",
      np.isfinite(X_test_clean.to_numpy()).all())
# Out:
# X_train_clean NaN: 0
# X_test_clean NaN : 0
# X_train_clean Inf: 0
# X_test_clean Inf : 0
#
# Training input is finite: True
# Testing input is finite: True

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv("../cic.csv")

X = df.drop(columns=["Label"])
y = df["Label"]

X_numeric = X.select_dtypes(include="number")

X_train, X_test, y_train, y_test = train_test_split(
    X_numeric,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("Training features:", X_train.shape)
print("Testing features :", X_test.shape)
print("Training target  :", y_train.shape)
print("Testing target   :", y_test.shape)

# %% [markdown]
# # Day 15 – LightGBM Training
#
# ## Objective
# Train the LightGBM baseline model using the common CIC-IDS2018 training input.
#
# ## Model
# LightGBM Classifier
#
# ## Training Input
# - Training features: 78 numeric features
# - Training rows: 838,860
# - Target: `Label`
# - Number of target classes: 3
#
# ## Evaluation
# The trained model will be evaluated on the test set using:
# - Accuracy
# - Weighted Precision
# - Weighted Recall
# - Weighted F1 Score
# - Classification Report
#
# ## Day 15 Scope
# - Load the dataset.
# - Create the common train/test split.
# - Handle invalid numeric values using training-data-derived medians.
# - Encode the target labels for LightGBM.
# - Train the LightGBM model.
# - Generate test predictions.
# - Calculate baseline evaluation metrics.
# - Save the trained model.
#
# Only the LightGBM model will be trained on Day 15.
