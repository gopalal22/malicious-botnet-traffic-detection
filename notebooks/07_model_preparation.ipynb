# %% [markdown]
# # Day 7 Completion Note
#
# ## Model Preparation Summary
#
# - CIC-IDS2018 dataset was loaded successfully.
# - Feature matrix contains 79 columns before numeric selection.
# - 78 numeric features were identified for model input.
# - `Timestamp` was identified as the only non-numeric feature.
# - Target variable `Label` contains 3 classes:
#   - Benign
#   - FTP-BruteForce
#   - SSH-Bruteforce
# - Numeric feature matrix and target variable contain the same number of rows.
# - All five required ML model objects were created successfully:
#   - Decision Tree
#   - Random Forest
#   - AdaBoost
#   - XGBoost
#   - LightGBM
#
# No model training was performed on Day 7.
# No missing values, duplicates, or dataset rows were modified.
#
# **Day 7 status: Completed**

# %%
# Final Day 7 input verification

print("Numeric features shape:", X_numeric.shape)
print("Target shape:", y.shape)

print("\nRows match:", len(X_numeric) == len(y))

print("\nNumber of target classes:", y.nunique())
print("Target classes:", y.unique())
# Out:
# Numeric features shape: (1048575, 78)
# Target shape: (1048575,)
#
# Rows match: True
#
# Number of target classes: 3
# Target classes: <StringArray>
# ['Benign', 'FTP-BruteForce', 'SSH-Bruteforce']
# Length: 3, dtype: str

# %%
# Display basic model configuration

print("Decision Tree:")
print(dt_model)

print("\nRandom Forest:")
print(rf_model)

print("\nAdaBoost:")
print(ada_model)

print("\nXGBoost:")
print(xgb_model)

print("\nLightGBM:")
print(lgbm_model)
# Out:
# Decision Tree:
# DecisionTreeClassifier(random_state=42)
#
# Random Forest:
# RandomForestClassifier(random_state=42)
#
# AdaBoost:
# AdaBoostClassifier(random_state=42)
#
# XGBoost:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)
#
# LightGBM:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# Create model objects
dt_model = DecisionTreeClassifier(random_state=42)
rf_model = RandomForestClassifier(random_state=42)
ada_model = AdaBoostClassifier(random_state=42)
xgb_model = XGBClassifier(random_state=42)
lgbm_model = LGBMClassifier(random_state=42)

print("Decision Tree: OK")
print("Random Forest: OK")
print("AdaBoost: OK")
print("XGBoost: OK")
print("LightGBM: OK")
# Out:
# Decision Tree: OK
# Random Forest: OK
# AdaBoost: OK
# XGBoost: OK
# LightGBM: OK

# %%
# Select numeric features for model preparation
X_numeric = X.select_dtypes(include="number")

print("Numeric feature shape:", X_numeric.shape)

print("\nNon-numeric columns:")
print(X.select_dtypes(exclude="number").columns.tolist())

print("\nMissing values in numeric features:")
print(X_numeric.isna().sum()[X_numeric.isna().sum() > 0])
# Out:
# Numeric feature shape: (1048575, 78)
#
# Non-numeric columns:
# ['Timestamp']
#
# Missing values in numeric features:
# Flow Byts/s    2277
# dtype: int64

# %%
import pandas as pd

# Load CIC-IDS2018 dataset
df = pd.read_csv("../cic.csv")

# Separate features and target
X = df.drop(columns=["Label"])
y = df["Label"]

print("Dataset shape:", df.shape)
print("Feature shape:", X.shape)
print("Target shape:", y.shape)

print("\nTarget classes:")
print(y.unique())
# Out:
# Dataset shape: (1048575, 80)
# Feature shape: (1048575, 79)
# Target shape: (1048575,)
#
# Target classes:
# <StringArray>
# ['Benign', 'FTP-BruteForce', 'SSH-Bruteforce']
# Length: 3, dtype: str

# %% [markdown]
# # Day 7 – Model Preparation
#
# ## Objective
#
# Prepare the common model input structure for the five machine learning models used in this project.
#
# The models are:
#
# 1. Decision Tree
# 2. Random Forest
# 3. AdaBoost
# 4. XGBoost
# 5. LightGBM
#
# ## Dataset
#
# Dataset: CIC-IDS2018
#
# The target column is `Label`.
#
# The `Timestamp` column is non-numeric and will not be used as a direct input to the ML models.
#
# Actual preprocessing and feature transformation will be handled as part of the preprocessing stage.
#
# ## Day 7 Scope
#
# - Verify the dataset and target structure.
# - Prepare the feature and target variables for the common ML pipeline.
# - Identify numeric model-input features.
# - Verify the five ML model objects can be created.
# - Do not perform model training yet.
