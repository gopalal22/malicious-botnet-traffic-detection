# %% [markdown]
# ## 5. LightGBM
#
# ### What is it?
# LightGBM is a gradient boosting framework based on decision trees.
#
# ### In our project
# Input: Network-flow features from CIC-IDS2018
# Output: Traffic class (`Label`)
#
# ### Advantages
# - Uses gradient boosting
# - Designed for efficient training
# - Suitable for large datasets
#
# ### Important parameters
# - `n_estimators`
# - `learning_rate`
# - `max_depth`
# - `num_leaves`
#
# ### Our model
# `LGBMClassifier()`

# %% [markdown]
# ## 4. XGBoost
#
# ### What is it?
# XGBoost is a gradient boosting algorithm that builds models sequentially to improve prediction performance.
#
# ### In our project
# Input: Network-flow features from CIC-IDS2018
# Output: Traffic class (`Label`)
#
# ### Advantages
# - Powerful boosting-based classifier
# - Can handle complex relationships in data
# - Suitable for classification
#
# ### Important parameters
# - `n_estimators`
# - `max_depth`
# - `learning_rate`
# - `subsample`
# - `colsample_bytree`
#
# ### Our model
# `XGBClassifier()`

# %% [markdown]
# ## 3. AdaBoost
#
# ### What is it?
# AdaBoost is an ensemble learning method that combines multiple weak learners to build a stronger classifier.
#
# ### In our project
# Input: Network-flow features from CIC-IDS2018
# Output: Traffic class (`Label`)
#
# ### Advantages
# - Combines multiple weak learners
# - Focuses more on difficult-to-classify samples
# - Can be used for classification
#
# ### Important parameters
# - `n_estimators`
# - `learning_rate`
#
# ### Our model
# `AdaBoostClassifier()`

# %% [markdown]
# ## 2. Random Forest
#
# ### What is it?
# Random Forest is an ensemble of multiple Decision Trees used together for classification.
#
# ### In our project
# Input: Network-flow features from CIC-IDS2018
# Output: Traffic class (`Label`)
#
# ### Advantages
# - Uses multiple Decision Trees
# - Useful for classification
# - Helps reduce dependence on a single tree
#
# ### Important parameters
# - `n_estimators`
# - `max_depth`
# - `min_samples_split`
# - `min_samples_leaf`
#
# ### Our model
# `RandomForestClassifier()`

# %% [markdown]
# ## 1. Decision Tree
#
# ### What is it?
# A Decision Tree predicts a class by repeatedly splitting the data based on feature conditions.
#
# ### In our project
# Input: Network-flow features from CIC-IDS2018
# Output: Traffic class (`Label`)
#
# ### Advantages
# - Easy to understand
# - Easy to visualize
# - Can handle classification problems
#
# ### Important parameters
# - `max_depth`
# - `min_samples_split`
# - `min_samples_leaf`
# - `criterion`
#
# ### Our model
# `DecisionTreeClassifier()`

# %% [markdown]
# # Day 3 - ML Algorithms Study
#
# ## Models Used
# 1. Decision Tree
# 2. Random Forest
# 3. AdaBoost
# 4. XGBoost
# 5. LightGBM
